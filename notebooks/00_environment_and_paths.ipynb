# %% [markdown]
# # Environment Setup & File Paths
#
# This notebook establishes the working environment for the project.
#
# It defines:
# - global imports,
# - the project root directory,
# - standardized paths for all data sources,
# - and quick checks to confirm key files exist.
#
# Every subsequent notebook builds on the structure defined here.
